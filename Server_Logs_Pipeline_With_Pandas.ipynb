# %% [markdown]
# ### Section : 1. Using Pandas 🐼
#
#
#
# This file Consists of creating basic ETL pipelines.
# here we use an API, to get requests i.e. Extract, Transform it according to our needs and then Load them into a CSV Dataset to further Work on them.

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
##EXTRACT :
def extract() ->dict:
  API_URL = "http://universities.hipolabs.com/search?country=United+States"
  data = requests.get(API_URL).json()
  return data

# %%
##TRANSFORM :
def transform(data:dict) -> pd.DataFrame:
    df = pd.DataFrame(data)
    print(f"Total Number of universities from API {len(data)}")
    df = df[df["name"].str.contains("New York")]
    print(f"Number of universities in New York {len(df)}")
    df['domains'] = [','.join(map(str, l)) for l in df['domains']]
    df['web_pages'] = [','.join(map(str, l)) for l in df['web_pages']]
    df = df.reset_index(drop=True)
    return df[["domains","country","web_pages","name"]]

# %%
def load(df:pd.DataFrame)-> None:
    """ Loads data into a sqllite database"""
    disk_engine = create_engine('sqlite:///my_lite_store.db')
    df.to_sql('cal_uni', disk_engine, if_exists='replace')

# %%
data = extract()
df = transform(data)
load(df)
# Out:
# Total Number of universities from API 2269
# Number of universities in New York 25

# %%
df.head()
# Out:
#       domains        country               web_pages  \
# 0    cuny.edu  United States    http://www.cuny.edu/
# 1    nyit.edu  United States    http://www.nyit.edu/
# 2     nyu.edu  United States     http://www.nyu.edu/
# 3    poly.edu  United States    http://www.poly.edu/
# 4  albany.edu  United States  http://www.albany.edu/
#
#                                      name
# 0             City University of New York
# 1        New York Institute of Technology
# 2                     New York University
# 3      Polytechnic University of New York
# 4  State University of New York at Albany
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
# ...
